# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
nfhs = pd.read_excel("Untitled spreadsheet (4).xlsx")
nfhs.head()
# Out:
#                   States/UTs   Area  literacy rate States  Unnamed: 4
# 0  Andaman & Nicobar Islands  Total           86.0     AN         NaN
# 1             Andhra Pradesh  Total           68.6     AP         NaN
# 2          Arunachal Pradesh  Total           73.8     AR         NaN
# 3                      Assam  Total           77.2     AS         NaN
# 4                      Bihar  Total           57.8     BR         NaN

# %%
df = pd.DataFrame(nfhs)
  
df
# Out:
#                                 States/UTs   Area  literacy rate States  \
# 0                Andaman & Nicobar Islands  Total           86.0     AN
# 1                           Andhra Pradesh  Total           68.6     AP
# 2                        Arunachal Pradesh  Total           73.8     AR
# 3                                    Assam  Total           77.2     AS
# 4                                    Bihar  Total           57.8     BR
# 5                               Chandigarh  Total           83.0     CH
# 6                             Chhattisgarh  Total           74.6     CG
# 7   Dadra and Nagar Haveli & Daman and Diu  Total           77.3     DH
# 8                                      Goa  Total           93.0     GA
# 9                                  Gujarat  Total           76.5     GJ
# 10                                 Haryana  Total           81.7     HR
# 11                        Himachal Pradesh  Total           91.7     HP
# ...

# %%
df.drop(df.columns[[4]], axis = 1, inplace = True)
  
df
# Out:
#                                 States/UTs   Area  literacy rate States
# 0                Andaman & Nicobar Islands  Total           86.0     AN
# 1                           Andhra Pradesh  Total           68.6     AP
# 2                        Arunachal Pradesh  Total           73.8     AR
# 3                                    Assam  Total           77.2     AS
# 4                                    Bihar  Total           57.8     BR
# 5                               Chandigarh  Total           83.0     CH
# 6                             Chhattisgarh  Total           74.6     CG
# 7   Dadra and Nagar Haveli & Daman and Diu  Total           77.3     DH
# 8                                      Goa  Total           93.0     GA
# 9                                  Gujarat  Total           76.5     GJ
# 10                                 Haryana  Total           81.7     HR
# 11                        Himachal Pradesh  Total           91.7     HP
# ...

# %%
ax = df.plot.bar(y='literacy rate',x='States', rot=0,width = 0.6, figsize=(12,5))
plt.xlabel('States',fontsize=20)
plt.ylabel('Literacy percentage',fontsize=20)
# Out:
# Text(0, 0.5, 'Literacy percentage')
